# %% [markdown]
# # EE P595 Homework 3: Identifying Malicious URLs (PyTorch)
#
# <span style="color:red">**Released Date: February 5, 2026**</span>
# <span style="color:red">**Due Date: February 22, 2026**</span>
#
# Build a 1D CNN to classify malicious HTTP request URLs using N-gram embeddings.
#
# **Key Concepts:** N-gram extraction, Co-occurrence matrix, TruncatedSVD, 1D CNN
#
# **Teammate:** _(Name if applicable)_

# %%
# %pip install torch tqdm assertpy scikit-learn pandas matplotlib
# Out:
# Requirement already satisfied: torch in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (2.10.0)
# Requirement already satisfied: tqdm in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (4.67.1)
# Collecting assertpy
#   Downloading assertpy-1.1.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: pandas in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: filelock in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from torch) (2026.1.0)
# Requirement already satisfied: numpy>=1.24.1 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.10.0 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/arpankapoor/miniconda3/envs/467/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)
# Building wheels for collected packages: assertpy
#   Building wheel for assertpy (pyproject.toml) ... done
#   Created wheel for assertpy: filename=assertpy-1.1-py3-none-any.whl size=42982 sha256=edb06d9f8ffd579f2885345a251de6e915927f415440dace23c89073887ac5fc
#   Stored in directory: /Users/arpankapoor/Library/Caches/pip/wheels/43/6a/e8/108096f3a70f5a0d317dc4e7db185e556adf1f7e1b50c2e8b4
# Successfully built assertpy
# Installing collected packages: assertpy
# Successfully installed assertpy-1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !tar -xJf waf-urls.tar.xz

# %% [markdown]
# ## 1. Data Loading

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Load WAF URLs dataset
df = pd.read_csv('waf-urls.csv')
print(f'Dataset: {len(df)} URLs')

# Split: 60% train, 20% val, 20% test
urls_tv, urls_test, labels_tv, labels_test = train_test_split(
    df['url'], df['label'], test_size=0.2, random_state=12345)
urls_train, urls_vali, labels_train, labels_vali = train_test_split(
    urls_tv, labels_tv, test_size=0.25, random_state=12345)

print(f'Train: {len(urls_train)}, Val: {len(urls_vali)}, Test: {len(urls_test)}')
# Out:
# Dataset: 60547 URLs
# Train: 36327, Val: 12110, Test: 12110

# %% [markdown]
# ## 2. N-Gram Functions

# %%
from assertpy import assert_that
from tqdm import tqdm

def iter_ngrams(text, n, start_symbol='\x00', end_symbol='\x01'):
    """Generate N-grams with start/end padding."""
    ## [ TODO 1 ] Implement N-gram generation
    # - Pad (n-1) start_symbols before text
    # - Pad n end_symbols after text
    # - Return generator of N-grams
    padded = (start_symbol * (n-1)) + text + (end_symbol * n)
    for i in range(len(padded) - n + 1):
        yield padded[i:i+n]

# Test
assert_that(list(iter_ngrams('/test', n=3))).is_equal_to([
    '\x00\x00/', '\x00/t', '/te', 'tes', 'est', 'st\x01', 't\x01\x01', '\x01\x01\x01'
])

# %%
def build_ngram_mapping(urls, n, rare_threshold=2):
    """Build bidirectional N-gram to index mapping."""
    ngram_count = {}
    
    print('Counting N-grams...')
    for url in tqdm(urls):
        for ngram in iter_ngrams(url, n):
            ## [ TODO 2.1 ] Count N-gram occurrences
            if ngram not in ngram_count:
                ngram_count[ngram] = 0
            ngram_count[ngram] += 1
    
    n2i, i2n = {}, []
    n_rare = 0
    
    print('Building mapping...')
    for ngram, count in tqdm(ngram_count.items()):
        ## [ TODO 2.2 ] Build mapping (only if count >= rare_threshold)
        # - Add to n2i and i2n if frequent
        # - Track n_rare for rare N-grams
        if count >= rare_threshold:
            n2i[ngram] = len(i2n)
            i2n.append(ngram)
        else:
            n_rare += 1
    
    print(f'Unique: {len(ngram_count)}, Kept: {len(i2n)}')
    return n2i, i2n

# Test
n2i_test, i2n_test = build_ngram_mapping(['/x', '/xyz/23', '/233'], n=3)
assert_that(len(n2i_test)).is_equal_to(5)
# Out:
# Counting N-grams...
# 100%|██████████| 3/3 [00:00<00:00, 46776.62it/s]
# Building mapping...
# 100%|██████████| 15/15 [00:00<00:00, 357469.09it/s]
# Unique: 15, Kept: 5

# %% [markdown]
# ## 3. Co-occurrence Matrix

# %%
from scipy.sparse import dok_matrix

def build_cooccurrence_matrix(urls, n, n2i_mapping, window_size):
    """Build normalized co-occurrence matrix."""
    n_ngram = len(n2i_mapping)
    unknown_idx = n_ngram
    co_matrix = dok_matrix((n_ngram+1, n_ngram+1))
    
    print(f'Building co-occurrence...')
    for url in tqdm(urls):
        prev_indices = []
        for ngram in iter_ngrams(url, n):
            ## [ TODO 3.1 ] Get N-gram index (unknown_idx if not found)
            idx = n2i_mapping.get(ngram, unknown_idx)
            
            ## [ TODO 3.2 ] Update co-occurrence for prev neighbors in window
            for prev in prev_indices[-window_size:]:
                co_matrix[prev, idx] += 1
                co_matrix[idx, prev] += 1
            
            prev_indices.append(idx)
    
    print('Normalizing...')
    row_sums = co_matrix.sum(axis=1)
    ## [ TODO 3.3 ] Normalize rows to probability distributions
    for (i, j) in tqdm(list(co_matrix.keys())):
        co_matrix[i, j] /= row_sums[i, 0]
    
    return co_matrix

# %%
# Build N-gram mapping and co-occurrence matrix
N = 4
WINDOW_SIZE = 5

n2i_urls, i2n_urls = build_ngram_mapping(urls_train, N)
cooccurrence_urls = build_cooccurrence_matrix(urls_train, N, n2i_urls, WINDOW_SIZE)
print(f'Co-occurrence shape: {cooccurrence_urls.shape}')
# Out:
# Counting N-grams...
# 100%|██████████| 36327/36327 [00:00<00:00, 118749.09it/s]
# Building mapping...
# 100%|██████████| 160195/160195 [00:00<00:00, 6926086.00it/s]
# Unique: 160195, Kept: 82844
# Building co-occurrence...
# 100%|██████████| 36327/36327 [02:27<00:00, 245.54it/s]
# Normalizing...
# 100%|██████████| 2542234/2542234 [00:16<00:00, 149775.36it/s]
# Co-occurrence shape: (82845, 82845)

# %% [markdown]
# ## 4. Embedding via TruncatedSVD

# %%
from sklearn.decomposition import TruncatedSVD

EMBEDDING_DIMS = 10

## [ TODO 4 ] Create TruncatedSVD and fit_transform co-occurrence matrix
# svd = TruncatedSVD(n_components=EMBEDDING_DIMS, n_iter=20, random_state=42)
# embedding_svd = svd.fit_transform(cooccurrence_urls)
embedding_svd = TruncatedSVD(n_components=EMBEDDING_DIMS, n_iter=20, random_state=42).fit_transform(cooccurrence_urls)

assert embedding_svd.shape == (len(n2i_urls)+1, EMBEDDING_DIMS)

# %% [markdown]
# ## 5. PyTorch Model

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
# Out:
# Device: cpu

# %%
def transform_urls(urls, padded_len, n, n2i_mapping, pad_symbol='\x01'):
    """Convert URLs to N-gram index sequences."""
    batch = np.empty((len(urls), padded_len + n), dtype=int)
    unknown_idx = len(n2i_mapping)
    
    for i, url in enumerate(urls):
        ## [ TODO 5.1 ] Pad URL to padded_len
        url = url[:padded_len]
        url = url + (pad_symbol * (padded_len - len(url)))
        
        ## [ TODO 5.2 ] Convert N-grams to indices
        for j, ngram in enumerate(iter_ngrams(url, n)):
            batch[i, j] = n2i_mapping.get(ngram, unknown_idx)
    
    return batch

# %%
class URLDataset(Dataset):
    def __init__(self, urls, labels, padded_len, n, n2i_mapping):
        self.data = transform_urls(list(urls), padded_len, n, n2i_mapping)
        self.labels = labels.values.astype(np.float32)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return torch.tensor(self.data[idx], dtype=torch.long), torch.tensor(self.labels[idx])

# %%
class URLCNN(nn.Module):
    """1D CNN for URL classification."""
    def __init__(self, n_ngram, embedding_weights, dropout=0.25):
        super().__init__()
        embed_dim = embedding_weights.shape[1]
        
        ## [ TODO 6.1 ] Embedding layer (frozen, initialized with embedding_weights)
        weights_tensor = torch.tensor(embedding_weights, dtype=torch.float32)
        self.embedding = nn.Embedding.from_pretrained(weights_tensor, freeze=True)
        
        ## [ TODO 6.2 ] Conv blocks
        # conv1: embed_dim -> 20, kernel=5, padding=2
        # conv2: 20 -> 40, kernel=5, padding=2
        # conv3: 40 -> 80, kernel=5, padding=2
        # pool1: MaxPool1d(2), pool2: MaxPool1d(5), pool3: MaxPool1d(5)
        self.conv1 = nn.Conv1d(in_channels=embed_dim, out_channels=20, kernel_size=5, padding=2)
        self.pool1 = nn.MaxPool1d(2)

        self.conv2 = nn.Conv1d(in_channels=20, out_channels=40, kernel_size=5, padding=2)
        self.pool2 = nn.MaxPool1d(5)

        self.conv3 = nn.Conv1d(in_channels=40, out_channels=80, kernel_size=5, padding=2)
        self.pool3 = nn.MaxPool1d(5)
        
        ## [ TODO 6.3 ] FC layers
        # fc1: 160 -> 16, fc2: 16 -> 1
        self.fc1 = nn.Linear(160, 16)
        self.fc2 = nn.Linear(16, 1)
    
    def forward(self, x):
        ## [ TODO 6.4 ] Forward pass
        # Embedding -> permute -> conv blocks -> flatten -> FC -> sigmoid
        x = self.embedding(x)
        x = x.permute(0, 2, 1)
        x = self.pool1(nn.functional.relu(self.conv1(x)))
        x = self.pool2(nn.functional.relu(self.conv2(x)))
        x = self.pool3(nn.functional.relu(self.conv3(x)))
        x = torch.flatten(x, 1)
        x = nn.functional.relu(self.fc1(x))
        x = self.fc2(x)
        return torch.sigmoid(x)

# %%
# Hyperparameters
BATCH_SIZE = 256
MAX_URL_LEN = 96
N_EPOCHS = 10

# Create datasets
train_dataset = URLDataset(urls_train, labels_train, MAX_URL_LEN, N, n2i_urls)
val_dataset = URLDataset(urls_vali, labels_vali, MAX_URL_LEN, N, n2i_urls)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

model = URLCNN(len(n2i_urls), embedding_svd).to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
def train_epoch(model, loader, criterion, optimizer):
    model.train()
    total_loss, correct, total = 0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        ## [ TODO 7 ] Training step
        # optimizer.zero_grad(), forward, loss, backward, step
        y = y.float()
        optimizer.zero_grad()
        output = model(x)
        output = output.squeeze()
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * len(y)
        correct += ((output > 0.5) == y).sum().item()
        total += len(y)
    return total_loss / total, correct / total

def evaluate(model, loader, criterion):
    model.eval()
    total_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            y = y.float()
            out = model(x)
            out = out.squeeze()
            total_loss += criterion(out, y).item() * len(y)
            correct += ((out > 0.5) == y).sum().item()
            total += len(y)
    return total_loss / total, correct / total

# %%
# Training loop
history = {'loss': [], 'acc': [], 'val_loss': [], 'val_acc': []}

for epoch in range(N_EPOCHS):
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer)
    val_loss, val_acc = evaluate(model, val_loader, criterion)
    history['loss'].append(train_loss)
    history['acc'].append(train_acc)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)
    print(f'Epoch {epoch+1}: Train Acc={train_acc:.4f}, Val Acc={val_acc:.4f}')

torch.save(model.state_dict(), './model-url-cnn.pt')
# Out:
# Epoch 1: Train Acc=0.8677, Val Acc=0.8825
# Epoch 2: Train Acc=0.8876, Val Acc=0.8866
# Epoch 3: Train Acc=0.9055, Val Acc=0.9156
# Epoch 4: Train Acc=0.9108, Val Acc=0.9089
# Epoch 5: Train Acc=0.9156, Val Acc=0.8964
# Epoch 6: Train Acc=0.9188, Val Acc=0.9234
# Epoch 7: Train Acc=0.9231, Val Acc=0.9201
# Epoch 8: Train Acc=0.9237, Val Acc=0.9229
# Epoch 9: Train Acc=0.9301, Val Acc=0.9280
# Epoch 10: Train Acc=0.9301, Val Acc=0.9306

# %% [markdown]
# ## 6. Evaluation

# %%
import matplotlib.pyplot as plt

## [ TODO 8 ] Plot loss and accuracy curves
epochs = range(1, len(history['loss']) + 1)
fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.plot(epochs, history['loss'], label='Training')
ax1.plot(epochs, history['val_loss'], label='Validation')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(epochs, history['acc'], label='Training')
ax2.plot(epochs, history['val_acc'], label='Validation')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

## [ TODO 9 ] Test evaluation
# - Create test dataset and loader
# - Predict and collect results
# - Print confusion matrix and classification report
test_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        out = model(x).squeeze()
        predicted_classes = (out > 0.5).long()
        all_preds.extend(predicted_classes.cpu().numpy())
        all_labels.extend(y.cpu().numpy())

print(confusion_matrix(all_labels, all_preds))
print(classification_report(all_labels, all_preds))
# Out:
# [[6517  629]
#  [ 212 4752]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.91      0.94      7146
#          1.0       0.88      0.96      0.92      4964
#
#     accuracy                           0.93     12110
#    macro avg       0.93      0.93      0.93     12110
# weighted avg       0.93      0.93      0.93     12110

# %% [markdown]
# ## Questions
#
# **Q1: Analyze model performance. Does lower loss indicate higher accuracy?** (2 pts)

# %% [markdown]
# **Your Answer:** Lower loss can indicate higher accuracy, but they do not always have a linear relatioship. Since a lower loss means increased confidence in the prediction, it can correlate to increased accuracy. Though, accuracy is a strict measure of whether or not the prediction was correct, such as > 0.5 or < 0.5. An edge case of this is overfitting, which can cause the loss to increase while the accuracy stays relatively the same.

# %% [markdown]
# **Q2: Is large window_size (e.g., 50) good? Other compression methods?** (2 pts)

# %% [markdown]
# **Your Answer:** No, since URLs can be short, windows this large would not be a good idea. The window should be small enough to show small, localized changes between adjacent ngrams. Capturing such a large area would not be very beneficial to showing changes between adjacent ngrams.

# %% [markdown]
# ## Submission
# Submit: `homework-3-student-20260205.ipynb` + `model-url-cnn.pt`
